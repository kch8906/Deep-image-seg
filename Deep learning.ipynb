# %%
## library import
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os
import re
from PIL import Image
import shutil
import random
import matplotlib.pyplot as plt

print(tf.__version__)
print(keras.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Data 준비하기

# %%
## google drive에서 압축된 dataset download
import gdown
url = 'https://drive.google.com/uc?id=1dIR9ANjUsV9dWa0pS9J0c2KUGMfpIRG0'
fname = 'oxford_pet.zip'
gdown.download(url, fname, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dIR9ANjUsV9dWa0pS9J0c2KUGMfpIRG0
# To: /content/oxford_pet.zip
# 811MB [00:08, 99.3MB/s]
# 'oxford_pet.zip'

# %%
## oxford_pet.zip이 보이는지 확인
# !ls -l
# Out:
# total 8
# drwx------ 5 root root 4096 Nov 24 08:14 drive
# drwxr-xr-x 1 root root 4096 Nov 13 17:33 sample_data

# %%
## 압축풀기
# !mkdir -p ./data1
# !unzip data1 -d data1
# Out:
# unzip:  cannot find or open data1, data1.zip or data1.ZIP.

# %%
## 압축이 풀린 directory 확인
# !ls oxford_pet
# Out:
# annotations  images

# %%
## directory 정보
cur_dir = os.getcwd()
data_dir = os.path.join(cur_dir, 'drive/MyDrive/dataset/data1.zip (Unzipped Files)')
image_dir = os.path.join(data_dir, 'image')
#bbox_dir = os.path.join(data_dir, 'annotations', 'xmls')
seg_dir = os.path.join(data_dir, 'label')

# %%
print(cur_dir)
# Out:
# /content

# %%
## image file 수 확인
image_files = [fname for fname in os.listdir(image_dir) if os.path.splitext(fname)[-1] == '.png']
print(len(image_files))
# Out:
# 851

# %%
## segmentation을 위한 annotation이 되어 있는 file의 수 확인
seg_files = [fname for fname in os.listdir(seg_dir) if os.path.splitext(fname)[-1] == '.png']
len(seg_files)
# Out:
# 851

# %%
## image file들을 읽어서 channel이 3이 아닌 image는 삭제, xml도 같이 삭제
for image_file in image_files:
  image_path = os.path.join(image_dir, image_file)
  seg_file = os.path.splitext(image_file)[0]+'.png'
  seg_path = os.path.join(seg_dir, seg_file)
  image = Image.open(image_path)
  image_mode = image.mode
  if image_mode != 'RGB':
    print(image_file, image_mode)
    image = np.asarray(image)
    print(image.shape)
    os.remove(image_path)
    os.remove(seg_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-75889b53a8d6> in <module>()
#       4   seg_file = os.path.splitext(image_file)[0]+'.png'
#       5   seg_path = os.path.join(seg_dir, seg_file)
# ----> 6   image = Image.open(image_path)
#       7   image_mode = image.mode
#       8   if image_mode != 'RGB':
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# KeyboardInterrupt:

# %%
## image file 수 확인
image_files = [fname for fname in os.listdir(image_dir) if os.path.splitext(fname)[-1] == '.png']
print(len(image_files))
# Out:
# 851

# %%
## segmentation을 위한 annotation이 되어 있는 file의 수 확인
seg_files = [fname for fname in os.listdir(seg_dir) if os.path.splitext(fname)[-1] == '.png']
len(seg_files)
# Out:
# 851

# %%
class_list = set()
for image_file in image_files:
    file_name = os.path.splitext(image_file)[0]
    class_name = re.sub('_\d+', '', file_name)
    class_list.add(class_name)
class_list = list(class_list)
print(len(class_list))
# Out:
# 3

# %%
class_list.sort()
class_list[0]
# Out:
# 'granulation'

# %%
class2idx = {cls:idx for idx, cls in enumerate(class_list)}
class2idx
# Out:
# {'granulation': 0, 'necrosis': 1, 'slough': 2}

# %%
## train, validation directory 생성
train_dir = os.path.join(data_dir, 'train')
val_dir = os.path.join(data_dir, 'validation')
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

# %%
image_files.sort()

# %%
image_files[:10]
# Out:
# ['granulation_0.png',
#  'granulation_1.png',
#  'granulation_10.png',
#  'granulation_100.png',
#  'granulation_101.png',
#  'granulation_102.png',
#  'granulation_103.png',
#  'granulation_104.png',
#  'granulation_105.png',
#  'granulation_106.png']

# %%
cnt = 0
previous_class = ""
for image_file in image_files:
    file_name = os.path.splitext(image_file)[0]
    class_name = re.sub('_\d+', '', file_name)
    if class_name == previous_class:
        cnt += 1
    else:
        cnt = 1
    if cnt <= 300:
        cpath = train_dir
    else:
        cpath = val_dir
    image_path = os.path.join(image_dir, image_file)
    shutil.copy(image_path, cpath)
    previous_class = class_name

# %%
train_images = os.listdir(train_dir)
val_images = os.listdir(val_dir)

# %%
print(len(train_images), len(val_images))
# Out:
# 729 122

# %%
train_images[:10]
# Out:
# ['granulation_0.png',
#  'granulation_1.png',
#  'granulation_10.png',
#  'granulation_100.png',
#  'granulation_101.png',
#  'granulation_102.png',
#  'granulation_103.png',
#  'granulation_104.png',
#  'granulation_105.png',
#  'granulation_106.png']

# %%
val_images[:10]
# Out:
# ['granulation_376.png',
#  'granulation_377.png',
#  'granulation_378.png',
#  'granulation_379.png',
#  'granulation_380.png',
#  'granulation_381.png',
#  'granulation_382.png',
#  'granulation_383.png',
#  'granulation_384.png',
#  'granulation_385.png']

# %%
# 임의의 image를 가져와서, seg map 확인
fnames = os.listdir(val_dir)
rnd_idx = random.randint(0, len(fnames)-1)
fname = fnames[rnd_idx]

fpath = os.path.join(val_dir, fname)
img = Image.open(fpath)
img = np.array(img)

## segmentation label
## 원래 label은 1: foreground, 2: background, 3: not classified 로 구성됨
## 이것을 0: background, 1 : foreground & not classified로 변경
sname = os.path.splitext(fname)[0] + '.png'
spath = os.path.join(seg_dir, sname)    
seg = Image.open(spath)
seg = np.array(seg)
# seg[seg>2] = 1
# seg[seg==2] = 0

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.subplot(1, 2, 2)
plt.imshow(seg)
plt.show()

# %% [markdown]
# ## TFRecord 만들기

# %%
IMG_SIZE = 224
N_TRAIN = len(train_images)
N_VAL = len(val_images)

# %%
## TFRecord 저장할 directory와 file 경로 설정
tfr_dir = os.path.join(data_dir, 'tfrecord')
os.makedirs(tfr_dir, exist_ok=True)

tfr_train_dir = os.path.join(tfr_dir, 'seg_train.tfr')
tfr_val_dir = os.path.join(tfr_dir, 'seg_val.tfr')

# %%
## TFRecord writer 생성
writer_train = tf.io.TFRecordWriter(tfr_train_dir)
writer_val = tf.io.TFRecordWriter(tfr_val_dir)

# %%
# The following functions can be used to convert a value to a type compatible
# with tf.Example.

def _bytes_feature(value):
  """Returns a bytes_list from a string / byte."""
  if isinstance(value, type(tf.constant(0))):
    value = value.numpy() # BytesList won't unpack a string from an EagerTensor.
  return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

def _float_feature(value):
  """Returns a float_list from a float / double."""
  return tf.train.Feature(float_list=tf.train.FloatList(value=[value]))

def _int64_feature(value):
  """Returns an int64_list from a bool / enum / int / uint."""
  return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

# %%
n_train = 0

train_files = os.listdir(train_dir)
for train_file in train_files:
  train_path = os.path.join(train_dir, train_file)
  image = Image.open(train_path)
  image = image.resize((IMG_SIZE, IMG_SIZE))
  bimage = image.tobytes()

  file_name = os.path.splitext(train_file)[0] #Bangal_101
  class_name = re.sub('_\d+', '', file_name)
  class_num = class2idx[class_name]

  if file_name[0].islower(): # dog
    bi_cls_num = 0
  else: # cat
    bi_cls_num = 1

  seg_name = file_name + '.png'
  seg_path = os.path.join(seg_dir, seg_name)
  seg = Image.open(seg_path)
  seg = seg.resize((IMG_SIZE, IMG_SIZE))
  seg = np.array(seg)
  seg[seg<255] = 0
  seg[seg==255] = 1
  bseg = seg.tobytes()

  example = tf.train.Example(features=tf.train.Features(feature={
      'image': _bytes_feature(bimage),
      'cls_num': _int64_feature(class_num),
      'bi_cls_num': _int64_feature(class_num),
      'seg': _bytes_feature(bseg)
  }))
  writer_train.write(example.SerializeToString())
  n_train += 1

writer_train.close()
print(n_train)
# Out:
# 729

# %%
n_val = 0

val_files = os.listdir(val_dir)
for val_file in val_files:
  val_path = os.path.join(val_dir, val_file)
  image = Image.open(val_path)
  image = image.resize((IMG_SIZE, IMG_SIZE))
  bimage = image.tobytes()

  file_name = os.path.splitext(val_file)[0] #Bangal_101
  class_name = re.sub('_\d+', '', file_name)
  class_num = class2idx[class_name]

  if file_name[0].islower(): # dog
    bi_cls_num = 0
  else: # cat
    bi_cls_num = 1

  seg_name = file_name + '.png'
  seg_path = os.path.join(seg_dir, seg_name)
  seg = Image.open(seg_path)
  seg = seg.resize((IMG_SIZE, IMG_SIZE))
  seg = np.array(seg)
  seg[seg<255] = 0
  seg[seg==255] = 1
  bseg = seg.tobytes()

  example = tf.train.Example(features=tf.train.Features(feature={
      'image': _bytes_feature(bimage),
      'cls_num': _int64_feature(class_num),
      'bi_cls_num': _int64_feature(class_num),
      'seg': _bytes_feature(bseg)
  }))
  writer_val.write(example.SerializeToString())
  n_val += 1

writer_val.close()
print(n_val)
# Out:
# 122

# %% [markdown]
# ## Segmentation

# %%
## Hyper Parameters
N_CLASS = len(class_list)
N_EPOCHS = 50
N_BATCH = 9
IMG_SIZE = 224
learning_rate = 0.0001
steps_per_epoch = N_TRAIN / N_BATCH
validation_steps = int(np.ceil(N_VAL / N_BATCH))

# %%
## tfrecord file을 data로 parsing해주는 function
def _parse_function(tfrecord_serialized):
    features={'image': tf.io.FixedLenFeature([], tf.string),
              'cls_num': tf.io.FixedLenFeature([], tf.int64),
              'bi_cls_num': tf.io.FixedLenFeature([], tf.int64),
              'seg': tf.io.FixedLenFeature([], tf.string)              
             }
    parsed_features = tf.io.parse_single_example(tfrecord_serialized, features)
    
    image = tf.io.decode_raw(parsed_features['image'], tf.uint8)    
    image = tf.reshape(image, [IMG_SIZE, IMG_SIZE, 3])
    image = tf.cast(image, tf.float32)/255.

    cls_label = tf.cast(parsed_features['cls_num'], tf.int64)
    bi_cls_label = tf.cast(parsed_features['bi_cls_num'], tf.int64)
    
    seg = tf.io.decode_raw(parsed_features['seg'], tf.uint8)    
    seg = tf.reshape(seg, [IMG_SIZE, IMG_SIZE, -1])
    seg = tf.cast(seg, tf.float32)
    seg = tf.keras.backend.mean(seg, axis=-1, keepdims=True)
    
    return image, seg

# %%
seg.shape
# Out:
# (224, 224, 3)

# %%
## train dataset 만들기
train_dataset = tf.data.TFRecordDataset(tfr_train_dir)
train_dataset = train_dataset.map(_parse_function, num_parallel_calls=tf.data.experimental.AUTOTUNE)
train_dataset = train_dataset.shuffle(buffer_size=N_TRAIN).prefetch(
    tf.data.experimental.AUTOTUNE).batch(N_BATCH).repeat()

# %%
## validation dataset 만들기
val_dataset = tf.data.TFRecordDataset(tfr_val_dir)
val_dataset = val_dataset.map(_parse_function, num_parallel_calls=tf.data.experimental.AUTOTUNE)
val_dataset = val_dataset.batch(N_BATCH).repeat()

# %%
## train dataset에서 1개의 image와 bbox를 읽어서 확인
for image, seg in val_dataset.take(3):
  plt.figure(figsize=(11,5))
  plt.subplot(1,2,1)
  plt.imshow(image[0])
  plt.subplot(1,2,2)
  plt.imshow(seg[0,:,:,0])
  
  plt.show()

# %%
image.shape
# Out:
# TensorShape([9, 224, 224, 3])

# %%
seg.shape
# Out:
# TensorShape([9, 224, 224, 1])

# %%
seg.shape
# Out:
# TensorShape([9, 224, 224, 1])

# %% [markdown]
# ### U-Net like model을 random intialization으로 학습하기

# %%
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, ReLU, MaxPooling2D, Dense, BatchNormalization, GlobalAveragePooling2D, Concatenate, UpSampling2D

# %%
def create_model():
    inputs = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    
    conv1_1 = Conv2D(64, 3, 1, 'SAME', activation='relu')(inputs)
    conv1_2 = Conv2D(64, 3, 1, 'SAME', activation='relu')(conv1_1)
    pool1_3 = MaxPooling2D()(conv1_2)
    
    conv2_1 = Conv2D(128, 3, 1, 'SAME', activation='relu')(pool1_3)
    conv2_2 = Conv2D(128, 3, 1, 'SAME', activation='relu')(conv2_1)
    pool2_3 = MaxPooling2D()(conv2_2)
    
    conv3_1 = Conv2D(256, 3, 1, 'SAME', activation='relu')(pool2_3)
    conv3_2 = Conv2D(256, 3, 1, 'SAME', activation='relu')(conv3_1)
    conv3_3 = Conv2D(256, 3, 1, 'SAME', activation='relu')(conv3_2)
    pool3_4 = MaxPooling2D()(conv3_3)
    
    conv4_1 = Conv2D(512, 3, 1, 'SAME', activation='relu')(pool3_4)
    conv4_2 = Conv2D(512, 3, 1, 'SAME', activation='relu')(conv4_1)
    conv4_3 = Conv2D(512, 3, 1, 'SAME', activation='relu')(conv4_2)
    pool4_4 = MaxPooling2D()(conv4_3)
    
    conv5_1 = Conv2D(512, 3, 1, 'SAME', activation='relu')(pool4_4)
    conv5_2 = Conv2D(512, 3, 1, 'SAME', activation='relu')(conv5_1)
    conv5_3 = Conv2D(512, 3, 1, 'SAME', activation='relu')(conv5_2)
    pool5_4 = MaxPooling2D()(conv5_3)    
    
    upconv6 = Conv2DTranspose(512, 5, 2, 'SAME', activation='relu')(pool5_4)
    concat6 = Concatenate()([conv5_3, upconv6])
    conv6 = Conv2D(512, 3, 1, 'SAME', activation='relu')(concat6)
                              
    upconv7 = Conv2DTranspose(512, 5, 2, 'SAME', activation='relu')(conv6)
    concat7 = Concatenate()([conv4_3, upconv7])
    conv7 = Conv2D(512, 3, 1, 'SAME', activation='relu')(concat7)
    
    upconv8 = Conv2DTranspose(256, 5, 2, 'SAME', activation='relu')(conv7)
    concat8 = Concatenate()([conv3_3, upconv8])
    conv8 = Conv2D(256, 3, 1, 'SAME', activation='relu')(concat8)
    
    upconv9 = Conv2DTranspose(128, 5, 2, 'SAME', activation='relu')(conv8)
    concat9 = Concatenate()([conv2_2, upconv9])
    conv9 = Conv2D(128, 3, 1, 'SAME', activation='relu')(concat9)
    
    upconv10 = Conv2DTranspose(64, 5, 2, 'SAME', activation='relu')(conv9)
    concat10 = Concatenate()([conv1_2, upconv10])
    conv10 = Conv2D(64, 3, 1, 'SAME', activation='relu')(concat10)
    
    conv11 = Conv2D(64, 3, 1, 'SAME', activation='relu')(conv10)
    
    conv12 = Conv2D(2, 1, 1, 'SAME', activation='softmax')(conv11)
    
    return keras.Model(inputs=inputs, outputs=conv12)

# %%
seg[1].shape
# Out:
# TensorShape([224, 224, 1])

# %%
model = create_model()
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 112, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 112, 112, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 256)  590080      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 512)  2359808     conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 512)  2359808     conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 14, 14, 512)  2359808     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 14, 14, 512)  2359808     conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 512)  2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 7, 7, 512)    0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 14, 14, 512)  6554112     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 14, 14, 1024) 0           conv2d_12[0][0]
#                                                                  conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 28, 28, 512)  6554112     conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 1024) 0           conv2d_9[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 512)  4719104     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 56, 56, 256)  3277056     conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 512)  0           conv2d_6[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 56, 56, 256)  1179904     concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 112, 112, 128 819328      conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 112, 112, 256 0           conv2d_3[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 112, 112, 128 295040      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 224, 224, 64) 204864      conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 224, 224, 128 0           conv2d_1[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 224, 224, 64) 73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 224, 224, 64) 36928       conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 224, 224, 2)  130         conv2d_18[0][0]
# ==================================================================================================
# Total params: 43,148,162
# Trainable params: 43,148,162
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
## learning rate scheduing
lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=learning_rate,
                                                          decay_steps=steps_per_epoch*10,
                                                          decay_rate=0.4,
                                                          staircase=True)
## optimizer는 Adam, loss는 sparse categorical crossentropy 사용
## label이 ont-hot으로 encoding 안 된 경우에 sparse categorical corssentropy 및 sparse categorical accuracy 사용
model.compile(keras.optimizers.Adam(lr_schedule), loss='sparse_categorical_crossentropy',
             metrics=['sparse_categorical_accuracy'])

# %%
## Train!
history = model.fit(train_dataset, steps_per_epoch=steps_per_epoch,                    
                    epochs=N_EPOCHS,
                    validation_data=val_dataset,
                    validation_steps=validation_steps)
# Out:
# Epoch 1/50
#  2/81 [..............................] - ETA: 20s - loss: 0.6896 - sparse_categorical_accuracy: 0.9415WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1838s vs `on_train_batch_end` time: 0.3357s). Check your callbacks.
# 81/81 [==============================] - 47s 580ms/step - loss: 0.2492 - sparse_categorical_accuracy: 0.9680 - val_loss: 0.0817 - val_sparse_categorical_accuracy: 0.9645
# Epoch 2/50
# 81/81 [==============================] - 44s 540ms/step - loss: 0.0661 - sparse_categorical_accuracy: 0.9696 - val_loss: 0.0524 - val_sparse_categorical_accuracy: 0.9786
# Epoch 3/50
# 81/81 [==============================] - 45s 551ms/step - loss: 0.0529 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.0386 - val_sparse_categorical_accuracy: 0.9890
# Epoch 4/50
# 81/81 [==============================] - 44s 546ms/step - loss: 0.0427 - sparse_categorical_accuracy: 0.9830 - val_loss: 0.0301 - val_sparse_categorical_accuracy: 0.9891
# Epoch 5/50
# 81/81 [==============================] - 44s 546ms/step - loss: 0.0363 - sparse_categorical_accuracy: 0.9853 - val_loss: 0.0279 - val_sparse_categorical_accuracy: 0.9902
# Epoch 6/50
# 81/81 [==============================] - 44s 548ms/step - loss: 0.0366 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.0256 - val_sparse_categorical_accuracy: 0.9908
# Epoch 7/50
# 81/81 [==============================] - 44s 548ms/step - loss: 0.0350 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0257 - val_sparse_categorical_accuracy: 0.9904
# Epoch 8/50
# 81/81 [==============================] - 44s 547ms/step - loss: 0.0336 - sparse_categorical_accuracy: 0.9864 - val_loss: 0.0290 - val_sparse_categorical_accuracy: 0.9904
# Epoch 9/50
# 81/81 [==============================] - 44s 546ms/step - loss: 0.0320 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.0227 - val_sparse_categorical_accuracy: 0.9911
# Epoch 10/50
# 81/81 [==============================] - 44s 545ms/step - loss: 0.0316 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.0230 - val_sparse_categorical_accuracy: 0.9916
# Epoch 11/50
# 81/81 [==============================] - 44s 547ms/step - loss: 0.0279 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.0208 - val_sparse_categorical_accuracy: 0.9920
# Epoch 12/50
# 81/81 [==============================] - 44s 545ms/step - loss: 0.0271 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.0202 - val_sparse_categorical_accuracy: 0.9920
# Epoch 13/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0259 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.0201 - val_sparse_categorical_accuracy: 0.9921
# Epoch 14/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0258 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.0196 - val_sparse_categorical_accuracy: 0.9925
# Epoch 15/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0241 - sparse_categorical_accuracy: 0.9903 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 0.9926
# Epoch 16/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0231 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0175 - val_sparse_categorical_accuracy: 0.9929
# Epoch 17/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0236 - sparse_categorical_accuracy: 0.9905 - val_loss: 0.0206 - val_sparse_categorical_accuracy: 0.9919
# Epoch 18/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0191 - val_sparse_categorical_accuracy: 0.9926
# Epoch 19/50
# 81/81 [==============================] - 45s 551ms/step - loss: 0.0221 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0217 - val_sparse_categorical_accuracy: 0.9917
# Epoch 20/50
# 81/81 [==============================] - 45s 552ms/step - loss: 0.0217 - sparse_categorical_accuracy: 0.9913 - val_loss: 0.0172 - val_sparse_categorical_accuracy: 0.9933
# Epoch 21/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9923 - val_loss: 0.0180 - val_sparse_categorical_accuracy: 0.9930
# Epoch 22/50
# 81/81 [==============================] - 44s 547ms/step - loss: 0.0183 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.0182 - val_sparse_categorical_accuracy: 0.9929
# Epoch 23/50
# 81/81 [==============================] - 44s 548ms/step - loss: 0.0178 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.0183 - val_sparse_categorical_accuracy: 0.9929
# Epoch 24/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 0.9927
# Epoch 25/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0169 - sparse_categorical_accuracy: 0.9932 - val_loss: 0.0184 - val_sparse_categorical_accuracy: 0.9931
# Epoch 26/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 0.9928
# Epoch 27/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 0.9930
# Epoch 28/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.0181 - val_sparse_categorical_accuracy: 0.9932
# Epoch 29/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0150 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.0185 - val_sparse_categorical_accuracy: 0.9932
# Epoch 30/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0147 - sparse_categorical_accuracy: 0.9940 - val_loss: 0.0183 - val_sparse_categorical_accuracy: 0.9933
# Epoch 31/50
# 81/81 [==============================] - 45s 549ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.0181 - val_sparse_categorical_accuracy: 0.9934
# Epoch 32/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0134 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0186 - val_sparse_categorical_accuracy: 0.9933
# Epoch 33/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.0190 - val_sparse_categorical_accuracy: 0.9932
# Epoch 34/50
# 81/81 [==============================] - 45s 549ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.0186 - val_sparse_categorical_accuracy: 0.9933
# Epoch 35/50
# 81/81 [==============================] - 45s 549ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.0191 - val_sparse_categorical_accuracy: 0.9932
# Epoch 36/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0125 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.0195 - val_sparse_categorical_accuracy: 0.9932
# Epoch 37/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0123 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0201 - val_sparse_categorical_accuracy: 0.9931
# Epoch 38/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0122 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0203 - val_sparse_categorical_accuracy: 0.9931
# Epoch 39/50
# 81/81 [==============================] - 44s 548ms/step - loss: 0.0119 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.0201 - val_sparse_categorical_accuracy: 0.9931
# Epoch 40/50
# 81/81 [==============================] - 44s 547ms/step - loss: 0.0117 - sparse_categorical_accuracy: 0.9952 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 0.9933
# Epoch 41/50
# 81/81 [==============================] - 44s 547ms/step - loss: 0.0114 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.0197 - val_sparse_categorical_accuracy: 0.9932
# Epoch 42/50
# 81/81 [==============================] - 44s 548ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.0199 - val_sparse_categorical_accuracy: 0.9932
# Epoch 43/50
# 81/81 [==============================] - 44s 548ms/step - loss: 0.0111 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0198 - val_sparse_categorical_accuracy: 0.9933
# Epoch 44/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0110 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0201 - val_sparse_categorical_accuracy: 0.9932
# Epoch 45/50
# 81/81 [==============================] - 44s 548ms/step - loss: 0.0109 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0204 - val_sparse_categorical_accuracy: 0.9932
# Epoch 46/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0109 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0203 - val_sparse_categorical_accuracy: 0.9932
# Epoch 47/50
# 81/81 [==============================] - 44s 548ms/step - loss: 0.0108 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0205 - val_sparse_categorical_accuracy: 0.9932
# Epoch 48/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0107 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0205 - val_sparse_categorical_accuracy: 0.9932
# Epoch 49/50
# 81/81 [==============================] - 44s 548ms/step - loss: 0.0106 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0207 - val_sparse_categorical_accuracy: 0.9932
# Epoch 50/50
# 81/81 [==============================] - 44s 547ms/step - loss: 0.0105 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0203 - val_sparse_categorical_accuracy: 0.9933

# %%
fig, ax = plt.subplots(2,2, figsize=(10,7))

ax[0,0].set_title('loss')
ax[0,0].plot(history.history['loss'],'r')
ax[0,1].set_title('sparse_categorical_accuracy')
ax[0,1].plot(history.history['sparse_categorical_accuracy'],'b')

ax[1,0].set_title('val_loss')
ax[1,0].plot(history.history['val_loss'],'r--')
ax[1,1].set_title('val_sparse_categorical_accuracy')
ax[1,1].plot(history.history['val_sparse_categorical_accuracy'],'b--')

# %%
## num_imgs만큼 validation dataset에서 읽어서 정답과 예측값 확인
import cv2
from PIL import Image
num_imgs = 10
idx = 0
for image, seg in train_dataset.take(num_imgs):
    plt.figure(figsize=(17, 6*num_imgs))
    plt.subplot(num_imgs,3,idx*3+1)
    plt.imshow(image[0])
    plt.title('Original Image')
    plt.subplot(num_imgs,3,idx*3+2)
    plt.imshow(seg[0,:,:,0], plt.cm.binary_r)
    plt.title('Ground Truth')

    plt.subplot(num_imgs,3,idx*3+3)
    ## validation data에 대한 예측값 생성
    prediction = model.predict(image)    
    pred = np.zeros_like(prediction)
    ## 0.5이상은 1로 나머지는 0으로 변환
    thr = 0.5
    pred[prediction>=thr] = 1
    pred[prediction<thr] = 0
    b = plt.imshow(pred[0,:,:,1], vmin=0, vmax=1, cmap='hot', interpolation='nearest')
    plt.title('Predicted Output')  
        
    plt.show() 
    idx += 1

# %%
## IOU 계산
avg_iou = 0
n = 0
for images, labels in val_dataset.take(validation_steps):  
  preds = model.predict(images)
  preds[preds>=0.5] = 1
  preds[preds<0.5] = 0

  psum = labels[...,0] + preds[...,1]

  union = np.array(psum)
  union[union>1] = 1.
  union = np.sum(union, axis=1)
  union = np.sum(union, axis=1)

  inter = np.array(psum)
  inter[inter==1] = 0.
  inter[inter>1] = 1.  
  inter = np.sum(inter, axis=1)
  inter = np.sum(inter, axis=1)
  
  iou = inter / union  
  avg_iou += np.sum(iou) / N_VAL

print('IOU : ',  avg_iou )
# Out:
# IOU :  0.8092550078376395

# %%
print('IOU : ',  avg_iou )
# Out:
# IOU :  0.8092550078376395

# %% [markdown]
# ## U-Net like model에 pretrained VGG를 활용하여 학습하기

# %%
from tensorflow.keras.utils import get_file

# %%
## vgg16 pretrained weights 다운로드
weight_path = get_file('vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5',
                      'https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5')
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step

# %%
def create_model():
    inputs = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    
    conv1_1 = Conv2D(64, 3, 1, 'SAME', activation='relu')(inputs)
    conv1_2 = Conv2D(64, 3, 1, 'SAME', activation='relu')(conv1_1)
    pool1_3 = MaxPooling2D()(conv1_2)
    
    conv2_1 = Conv2D(128, 3, 1, 'SAME', activation='relu')(pool1_3)
    conv2_2 = Conv2D(128, 3, 1, 'SAME', activation='relu')(conv2_1)
    pool2_3 = MaxPooling2D()(conv2_2)
    
    conv3_1 = Conv2D(256, 3, 1, 'SAME', activation='relu')(pool2_3)
    conv3_2 = Conv2D(256, 3, 1, 'SAME', activation='relu')(conv3_1)
    conv3_3 = Conv2D(256, 3, 1, 'SAME', activation='relu')(conv3_2)
    pool3_4 = MaxPooling2D()(conv3_3)
    
    conv4_1 = Conv2D(512, 3, 1, 'SAME', activation='relu')(pool3_4)
    conv4_2 = Conv2D(512, 3, 1, 'SAME', activation='relu')(conv4_1)
    conv4_3 = Conv2D(512, 3, 1, 'SAME', activation='relu')(conv4_2)
    pool4_4 = MaxPooling2D()(conv4_3)
    
    conv5_1 = Conv2D(512, 3, 1, 'SAME', activation='relu')(pool4_4)
    conv5_2 = Conv2D(512, 3, 1, 'SAME', activation='relu')(conv5_1)
    conv5_3 = Conv2D(512, 3, 1, 'SAME', activation='relu')(conv5_2)
    pool5_4 = MaxPooling2D()(conv5_3)
    
    ## loading vgg16 pretrained weights
    vgg = keras.Model(inputs, pool5_4)
    vgg.load_weights(weight_path)
    
    upconv6 = Conv2DTranspose(512, 5, 2, 'SAME', activation='relu')(pool5_4)
    concat6 = Concatenate()([conv5_3, upconv6])
    conv6 = Conv2D(512, 3, 1, 'SAME', activation='relu')(concat6)
                              
    upconv7 = Conv2DTranspose(512, 5, 2, 'SAME', activation='relu')(conv6)
    concat7 = Concatenate()([conv4_3, upconv7])
    conv7 = Conv2D(512, 3, 1, 'SAME', activation='relu')(concat7)
    
    upconv8 = Conv2DTranspose(256, 5, 2, 'SAME', activation='relu')(conv7)
    concat8 = Concatenate()([conv3_3, upconv8])
    conv8 = Conv2D(256, 3, 1, 'SAME', activation='relu')(concat8)
    
    upconv9 = Conv2DTranspose(128, 5, 2, 'SAME', activation='relu')(conv8)
    concat9 = Concatenate()([conv2_2, upconv9])
    conv9 = Conv2D(128, 3, 1, 'SAME', activation='relu')(concat9)
    
    upconv10 = Conv2DTranspose(64, 5, 2, 'SAME', activation='relu')(conv9)
    concat10 = Concatenate()([conv1_2, upconv10])
    conv10 = Conv2D(64, 3, 1, 'SAME', activation='relu')(concat10)
    
    conv11 = Conv2D(64, 3, 1, 'SAME', activation='relu')(conv10)
    
    conv12 = Conv2D(2, 1, 1, 'SAME', activation='softmax')(conv11)
    
    return keras.Model(inputs=inputs, outputs=conv12)

# %%
model = create_model()
model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 224, 224, 64) 1792        input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 224, 224, 64) 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 112, 112, 64) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 112, 112, 128 73856       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 112, 112, 128 147584      conv2d_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 56, 56, 128)  0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 56, 56, 256)  295168      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 28, 28, 256)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 512)  1180160     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 512)  2359808     conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 28, 28, 512)  2359808     conv2d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 512)  0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 512)  2359808     max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 512)  2359808     conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 512)  2359808     conv2d_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 7, 7, 512)    0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 14, 14, 512)  6554112     max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 1024) 0           conv2d_32[0][0]
#                                                                  conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 512)  4719104     concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 28, 28, 512)  6554112     conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 28, 28, 1024) 0           conv2d_29[0][0]
#                                                                  conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 28, 28, 512)  4719104     concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 56, 56, 256)  3277056     conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 56, 56, 512)  0           conv2d_26[0][0]
#                                                                  conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 56, 56, 256)  1179904     concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 112, 112, 128 819328      conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 112, 112, 256 0           conv2d_23[0][0]
#                                                                  conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 112, 112, 128 295040      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 224, 224, 64) 204864      conv2d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 224, 224, 128 0           conv2d_21[0][0]
#                                                                  conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 224, 224, 64) 73792       concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 224, 224, 64) 36928       conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 224, 224, 2)  130         conv2d_38[0][0]
# ==================================================================================================
# Total params: 43,148,162
# Trainable params: 43,148,162
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
## learning rate scheduing
lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=learning_rate,
                                                          decay_steps=steps_per_epoch*10,
                                                          decay_rate=0.4,
                                                          staircase=True)
## optimizer는 Adam, loss는 sparse categorical crossentropy 사용
## label이 ont-hot으로 encoding 안 된 경우에 sparse categorical corssentropy 및 sparse categorical accuracy 사용
model.compile(keras.optimizers.Adam(lr_schedule), loss='sparse_categorical_crossentropy',
             metrics=['sparse_categorical_accuracy'])

# %%
## Train!
history = model.fit(train_dataset, steps_per_epoch=steps_per_epoch,                    
                    epochs=N_EPOCHS,
                    validation_data=val_dataset,
                    validation_steps=validation_steps)
# Out:
# Epoch 1/50
#  2/81 [..............................] - ETA: 32s - loss: 1.9808 - sparse_categorical_accuracy: 0.0447WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1820s vs `on_train_batch_end` time: 0.3139s). Check your callbacks.
# 81/81 [==============================] - 45s 551ms/step - loss: 0.1411 - sparse_categorical_accuracy: 0.9451 - val_loss: 0.0548 - val_sparse_categorical_accuracy: 0.9741
# Epoch 2/50
# 81/81 [==============================] - 45s 554ms/step - loss: 0.0376 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.0185 - val_sparse_categorical_accuracy: 0.9930
# Epoch 3/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0270 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.0187 - val_sparse_categorical_accuracy: 0.9924
# Epoch 4/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0205 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.0160 - val_sparse_categorical_accuracy: 0.9936
# Epoch 5/50
# 81/81 [==============================] - 44s 548ms/step - loss: 0.0170 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.0132 - val_sparse_categorical_accuracy: 0.9949
# Epoch 6/50
# 81/81 [==============================] - 44s 549ms/step - loss: 0.0154 - sparse_categorical_accuracy: 0.9940 - val_loss: 0.0154 - val_sparse_categorical_accuracy: 0.9939
# Epoch 7/50
# 81/81 [==============================] - 45s 551ms/step - loss: 0.0145 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.0129 - val_sparse_categorical_accuracy: 0.9950
# Epoch 8/50
# 81/81 [==============================] - 45s 551ms/step - loss: 0.0133 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.0119 - val_sparse_categorical_accuracy: 0.9953
# Epoch 9/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0116 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0113 - val_sparse_categorical_accuracy: 0.9956
# Epoch 10/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0110 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0111 - val_sparse_categorical_accuracy: 0.9957
# Epoch 11/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0120 - val_sparse_categorical_accuracy: 0.9956
# Epoch 12/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0110 - val_sparse_categorical_accuracy: 0.9958
# Epoch 13/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.0118 - val_sparse_categorical_accuracy: 0.9958
# Epoch 14/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.0114 - val_sparse_categorical_accuracy: 0.9958
# Epoch 15/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0074 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0127 - val_sparse_categorical_accuracy: 0.9958
# Epoch 16/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0124 - val_sparse_categorical_accuracy: 0.9959
# Epoch 17/50
# 81/81 [==============================] - 45s 551ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 0.9960
# Epoch 18/50
# 81/81 [==============================] - 45s 552ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0132 - val_sparse_categorical_accuracy: 0.9958
# Epoch 19/50
# 81/81 [==============================] - 45s 551ms/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 0.9959
# Epoch 20/50
# 81/81 [==============================] - 44s 548ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0129 - val_sparse_categorical_accuracy: 0.9959
# Epoch 21/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0052 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0134 - val_sparse_categorical_accuracy: 0.9960
# Epoch 22/50
# 81/81 [==============================] - 45s 551ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0136 - val_sparse_categorical_accuracy: 0.9960
# Epoch 23/50
# 81/81 [==============================] - 45s 551ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0141 - val_sparse_categorical_accuracy: 0.9960
# Epoch 24/50
# 81/81 [==============================] - 45s 551ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0145 - val_sparse_categorical_accuracy: 0.9960
# Epoch 25/50
# 81/81 [==============================] - 44s 548ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0150 - val_sparse_categorical_accuracy: 0.9959
# Epoch 26/50
# 81/81 [==============================] - 44s 547ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0149 - val_sparse_categorical_accuracy: 0.9959
# Epoch 27/50
# 81/81 [==============================] - 45s 552ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0156 - val_sparse_categorical_accuracy: 0.9959
# Epoch 28/50
# 81/81 [==============================] - 45s 551ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0153 - val_sparse_categorical_accuracy: 0.9960
# Epoch 29/50
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0166 - val_sparse_categorical_accuracy: 0.9957
# Epoch 30/50
# 81/81 [==============================] - 44s 543ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0146 - val_sparse_categorical_accuracy: 0.9960
# Epoch 31/50
# 81/81 [==============================] - 44s 545ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0161 - val_sparse_categorical_accuracy: 0.9959
# Epoch 32/50
# 81/81 [==============================] - 44s 543ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0161 - val_sparse_categorical_accuracy: 0.9959
# Epoch 33/50
# 81/81 [==============================] - 44s 542ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0164 - val_sparse_categorical_accuracy: 0.9959
# Epoch 34/50
# 81/81 [==============================] - 44s 542ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0165 - val_sparse_categorical_accuracy: 0.9959
# Epoch 35/50
# 81/81 [==============================] - 44s 541ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0168 - val_sparse_categorical_accuracy: 0.9959
# Epoch 36/50
# 81/81 [==============================] - 44s 541ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0166 - val_sparse_categorical_accuracy: 0.9959
# Epoch 37/50
# 81/81 [==============================] - 44s 542ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0170 - val_sparse_categorical_accuracy: 0.9959
# Epoch 38/50
# 81/81 [==============================] - 44s 542ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0171 - val_sparse_categorical_accuracy: 0.9959
# Epoch 39/50
# 81/81 [==============================] - 44s 542ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0172 - val_sparse_categorical_accuracy: 0.9959
# Epoch 40/50
# 81/81 [==============================] - 44s 542ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0172 - val_sparse_categorical_accuracy: 0.9959
# Epoch 41/50
# 81/81 [==============================] - 44s 540ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0174 - val_sparse_categorical_accuracy: 0.9959
# Epoch 42/50
# 81/81 [==============================] - 44s 540ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0174 - val_sparse_categorical_accuracy: 0.9959
# Epoch 43/50
# 81/81 [==============================] - 44s 541ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0175 - val_sparse_categorical_accuracy: 0.9959
# Epoch 44/50
# 81/81 [==============================] - 44s 543ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0176 - val_sparse_categorical_accuracy: 0.9959
# Epoch 45/50
# 81/81 [==============================] - 44s 542ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0176 - val_sparse_categorical_accuracy: 0.9959
# Epoch 46/50
# 81/81 [==============================] - 44s 542ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0177 - val_sparse_categorical_accuracy: 0.9959
# Epoch 47/50
# 81/81 [==============================] - 44s 541ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0178 - val_sparse_categorical_accuracy: 0.9959
# Epoch 48/50
# 81/81 [==============================] - 44s 541ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0179 - val_sparse_categorical_accuracy: 0.9959
# Epoch 49/50
# 81/81 [==============================] - 44s 542ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0178 - val_sparse_categorical_accuracy: 0.9959
# Epoch 50/50
# 81/81 [==============================] - 44s 542ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0180 - val_sparse_categorical_accuracy: 0.9959

# %%
## num_imgs만큼 validation dataset에서 읽어서 정답과 예측값 확인
num_imgs = 10
idx = 0
for image, seg in val_dataset.take(num_imgs):
    plt.figure(figsize=(17, 6*num_imgs))
    plt.subplot(num_imgs,3,idx*3+1)
    plt.imshow(image[0])
    plt.subplot(num_imgs,3,idx*3+2)
    plt.imshow(seg[0,:,:,0], plt.cm.binary_r)

    plt.subplot(num_imgs,3,idx*3+3)
    ## validation data에 대한 예측값 생성
    prediction = model.predict(image)    
    pred = np.zeros_like(prediction)
    ## 0.5이상은 1로 나머지는 0으로 변환
    thr = 0.5
    pred[prediction>=thr] = 1
    pred[prediction<thr] = 0
    plt.imshow(pred[0,:,:,1], vmin=0, vmax=1, cmap='hot', interpolation='nearest')
    plt.show() 
    idx += 1

# %%
avg_iou = 0
n = 0
for images, labels in val_dataset.take(validation_steps):  
  preds = model.predict(images)
  preds[preds>=0.5] = 1
  preds[preds<0.5] = 0

  psum = labels[...,0] + preds[...,1]

  union = np.array(psum)
  union[union>1] = 1.
  union = np.sum(union, axis=1)
  union = np.sum(union, axis=1)

  inter = np.array(psum)
  inter[inter==1] = 0.
  inter[inter>1] = 1.  
  inter = np.sum(inter, axis=1)
  inter = np.sum(inter, axis=1)
  
  iou = inter / union  
  avg_iou += np.sum(iou) / N_VAL

print('IOU : ',  avg_iou)
# Out:
# IOU :  nan
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide

# %%
print('IOU : ',  avg_iou )
# Out:
# IOU :  0.8582422850561925

# %%
fig, ax = plt.subplots(2,2, figsize=(10,7))

ax[0,0].set_title('loss')
ax[0,0].plot(history.history['loss'],'r')
ax[0,1].set_title('sparse_categorical_accuracy')
ax[0,1].plot(history.history['sparse_categorical_accuracy'],'b')

ax[1,0].set_title('val_loss')
ax[1,0].plot(history.history['val_loss'],'r--')
ax[1,1].set_title('val_sparse_categorical_accuracy')
ax[1,1].plot(history.history['val_sparse_categorical_accuracy'],'b--')

# %% [markdown]
# ## 새로운 Image로 Test하기

# %%
## Image upload 후 실행
image = Image.open('/content/drive/MyDrive/dataset/3.jpg')
image = image.resize((224, 224))
image = np.array(image)
image = image/255.

# %%
plt.imshow(image)
plt.show()

# %%
image = np.reshape(image, (1, 224, 224, 3))

# %%
prediction = model.predict(image)
prediction.shape
# Out:
# (1, 224, 224, 2)

# %%
pred = np.zeros_like(prediction)
## 0.5이상은 1로 나머지는 0으로 변환
thr = 0.5
pred[prediction>=thr] = 1
pred[prediction<thr] = 0

# %%
## 예측 결과 확인
plt.figure(figsize=(11,5))
plt.subplot(1,2,1)
plt.imshow(image[0])
plt.subplot(1,2,2)
plt.imshow(pred[0,:,:,1], vmin=0, vmax=1, cmap='hot', interpolation='nearest')
plt.show()
